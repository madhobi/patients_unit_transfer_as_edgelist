# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
bedflow_2000 = pd.read_csv('bedflow_2000_cleaned.csv')
print(bedflow_2000.shape)
bedflow_2000.columns
# Out:
# (2234899, 7)
# Index(['hospitalid', 'patientid', 'admissionid', 'bedflowid', 'arrivaltime',
#        'dismissaltime', 'nhsnunitid'],
#       dtype='object')

# %%
bedflow_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2234899 entries, 0 to 2234898
# Data columns (total 7 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   hospitalid     int64
#  1   patientid      int64
#  2   admissionid    int64
#  3   bedflowid      int64
#  4   arrivaltime    object
#  5   dismissaltime  object
#  6   nhsnunitid     int64
# dtypes: int64(5), object(2)
# memory usage: 119.4+ MB

# %%
bf_working_cols = ['patientid', 'admissionid', 'bedflowid', 'arrivaltime', 'dismissaltime', 'nhsnunitid']
bf = bedflow_2000[bf_working_cols].copy()
# bf.head()

# %%
bf['arrivaltime'] = pd.to_datetime(bf['arrivaltime'])
bf['dismissaltime'] = pd.to_datetime(bf['dismissaltime'])
bf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2234899 entries, 0 to 2234898
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   patientid      int64
#  1   admissionid    int64
#  2   bedflowid      int64
#  3   arrivaltime    datetime64[ns]
#  4   dismissaltime  datetime64[ns]
#  5   nhsnunitid     int64
# dtypes: datetime64[ns](2), int64(4)
# memory usage: 102.3 MB

# %%
# sorting so that the nhsnunits are ordered by time of visit
bf_sorted = bf.sort_values(['patientid', 'admissionid', 'bedflowid', 'arrivaltime'], ascending=[True, True, True, True]).reset_index(drop=True).copy()
# bf_sorted.head()

# %%
# creating the next unit column by shifting the nhsnunitid
# the nhsnunitid is the current unit
# so basically the transfer is from current unit to next unit
# also creating the prev_unit column to identify the entry units
# when next_unit is null, that is the exit point
# when prev_unit is null that is the entry point
bf_sorted['prev_unit'] = bf_sorted.groupby(['patientid', 'admissionid'])['nhsnunitid'].shift(1).fillna(0)
bf_sorted['next_unit'] = bf_sorted.groupby(['patientid', 'admissionid'])['nhsnunitid'].shift(-1).fillna(0)
# bf_sorted.head(20)
bf_sorted['next_unit'] = bf_sorted['next_unit'].astype(int)
bf_sorted['prev_unit'] = bf_sorted['prev_unit'].astype(int)

# creating two dummy id for entry and exit unit
# id 1000 : entry
# id 1001 : exit
bf_sorted['next_unit'] = bf_sorted['next_unit'].replace(0, 1001)
bf_sorted['prev_unit'] = bf_sorted['prev_unit'].replace(0, 1000)
print(bf_sorted.shape)
bf_sorted.columns
# Out:
# (2234899, 8)
# Index(['patientid', 'admissionid', 'bedflowid', 'arrivaltime', 'dismissaltime',
#        'nhsnunitid', 'prev_unit', 'next_unit'],
#       dtype='object')

# %%
# functions for the edgelist calculation

def get_monthly_bedflow(df, year=None, month=None):
    df_filtered = df.copy()
    # if(hid):
    #     df_filtered = df_filtered[(df_filtered['hospitalid'] == hid)]
    if(year):
        df_filtered = df_filtered[(df_filtered['dismissaltime'].dt.year == year)]
    if(month):
        df_filtered = df_filtered[(df_filtered['dismissaltime'].dt.month == month)]

    return df_filtered

def generate_edgelist(bf_month, source, dest, source_rename, dest_rename, self_edge=True):
    
    # edge_list = bf_month.groupby(['nhsnunitid', 'next_unit']).size().reset_index(name='count')
    edge_list = bf_month.groupby([source, dest]).size().reset_index(name='count')
    edge_list.rename(columns={source:source_rename, dest:dest_rename}, inplace=True)
    
    if(self_edge == False):
        print('need to remove self-edge i.e. source and dest are same')
        edge_list = edge_list[edge_list[source_rename] != edge_list[dest_rename]].copy()
    
    return edge_list

def convert_unitid_to_unitname(edgelist, source_col, dest_col, df_unitname, id_col):
    
    edgelist[source_col] = edgelist[source_col].map(df_unitname.set_index(id_col)['nhsnunitname'])
    edgelist[dest_col] = edgelist[dest_col].map(df_unitname.set_index(id_col)['nhsnunitname'])
    
    return edgelist

def save_edgelist(df_edgelist, savepath, file_prefix, year, month):
    
    filename = file_prefix+"_"+str(year)+"_"+str(month)+".csv"    
    if not os.path.isdir(savepath):
            os.makedirs(savepath)
    df_edgelist.to_csv(savepath+filename, index=False)
    print('Saved edge list for year '+str(year)+' and month '+str(month))

# %%
units = pd.read_csv('nhsnunit_extended_dason.csv')
unitname = units[['nhsnunitid', 'nhsnunitname']]
print(unitname.shape)
unitname
# Out:
# (96, 2)
#     nhsnunitid                               nhsnunitname
# 0            1                   24-Hour Observation Area
# 1            3                       Administrative Areas
# 2            4  Adult Step Down Unit (post-critical care)
# 3            8                             Allergy Clinic
# 4            9                  Ambulatory Surgery Center
# ..         ...                                        ...
# 91         300          Neonatal Critical Care (Level IV)
# 92         998                            Acute Home Care
# 93         999                                    Unknown
# 94        1000                                      Entry
# 95        1001                                       Exit
#
# [96 rows x 2 columns]

# %%
# calculating and saving edge list

year_list = list(range(2016, 2022)) #[2016, 2017, 2018, 2019, 2020, 2021]
month_list = list(range(1, 13))
source_unit, dest_unit = 'nhsnunitid', 'next_unit'
source_entry, dest_entry_unit = 'prev_unit', 'nhsnunitid'
source_rename, dest_rename = 'source', 'destination'
id_col = 'nhsnunitid'
self_edge = False
# file_prefix = "edgelist_hid2000"
# file_prefix = "edgelist_removing_self_edge_hid2000"
# print(year_list)
# print(month_list)
for year in year_list:
    for month in month_list:
        print('Y-M: '+str(year)+'-'+str(month))
        bf_month = get_monthly_bedflow(bf_sorted, year, month)
        bf_month_entry = bf_month[bf_month['prev_unit'] == 1000].copy()
        edge_list_month = generate_edgelist(bf_month, source_unit, dest_unit, source_rename, dest_rename, self_edge)
        print('edgelist shape without entry: ', edge_list_month.shape)
        edge_list_entry = generate_edgelist(bf_month_entry, source_entry, dest_entry_unit, source_rename, dest_rename, self_edge)
        edge_list_month = pd.concat([edge_list_entry, edge_list_month], axis=0)
        edge_list_month_name_converted = convert_unitid_to_unitname(edge_list_month.copy(), source_rename, dest_rename, unitname, id_col)
        print('edgelist shape with entry: ', edge_list_month.shape)        
        print('bedflow shape for this month: ', bf_month.shape)
        if(self_edge == True):
            folder_name = 'edgelist_hid_2000'
            file_prefix = "edgelist_hid2000"
        else:
            folder_name = 'edgelist_hid_2000_removing_self_edge'
            file_prefix = "edgelist_removing_self_edge_hid2000"
            
        savepath_unitid = './edgelist_hid_2000_unitid/'+folder_name+'/'+str(year)+'/'
        savepath_unitname = './edgelist_hid_2000_unitname/'+folder_name+'/'+str(year)+'/'
        save_edgelist(edge_list_month, savepath_unitid, file_prefix, year, month)        
        save_edgelist(edge_list_month_name_converted, savepath_unitname, file_prefix, year, month)        
        # break
    # break
# Out:
# Y-M: 2016-1
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (259, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (288, 3)
# bedflow shape for this month:  (28953, 8)
# Saved edge list for year 2016 and month 1
# Saved edge list for year 2016 and month 1
# Y-M: 2016-2
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (263, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (293, 3)
# bedflow shape for this month:  (28851, 8)
# Saved edge list for year 2016 and month 2
# Saved edge list for year 2016 and month 2
# Y-M: 2016-3
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (275, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (304, 3)
# bedflow shape for this month:  (32661, 8)
# Saved edge list for year 2016 and month 3
# Saved edge list for year 2016 and month 3
# Y-M: 2016-4
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (272, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (301, 3)
# bedflow shape for this month:  (30509, 8)
# Saved edge list for year 2016 and month 4
# Saved edge list for year 2016 and month 4
# Y-M: 2016-5
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (264, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (293, 3)
# bedflow shape for this month:  (29987, 8)
# Saved edge list for year 2016 and month 5
# Saved edge list for year 2016 and month 5
# Y-M: 2016-6
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (286, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (315, 3)
# bedflow shape for this month:  (29909, 8)
# Saved edge list for year 2016 and month 6
# Saved edge list for year 2016 and month 6
# Y-M: 2016-7
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (277, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (306, 3)
# bedflow shape for this month:  (30945, 8)
# Saved edge list for year 2016 and month 7
# Saved edge list for year 2016 and month 7
# Y-M: 2016-8
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (274, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (303, 3)
# bedflow shape for this month:  (32634, 8)
# Saved edge list for year 2016 and month 8
# Saved edge list for year 2016 and month 8
# Y-M: 2016-9
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (274, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (303, 3)
# bedflow shape for this month:  (31717, 8)
# Saved edge list for year 2016 and month 9
# Saved edge list for year 2016 and month 9
# Y-M: 2016-10
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (268, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (297, 3)
# bedflow shape for this month:  (31101, 8)
# Saved edge list for year 2016 and month 10
# Saved edge list for year 2016 and month 10
# Y-M: 2016-11
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (275, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (304, 3)
# bedflow shape for this month:  (30334, 8)
# Saved edge list for year 2016 and month 11
# Saved edge list for year 2016 and month 11
# Y-M: 2016-12
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (292, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (322, 3)
# bedflow shape for this month:  (32018, 8)
# Saved edge list for year 2016 and month 12
# Saved edge list for year 2016 and month 12
# Y-M: 2017-1
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (311, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (340, 3)
# bedflow shape for this month:  (31747, 8)
# Saved edge list for year 2017 and month 1
# Saved edge list for year 2017 and month 1
# Y-M: 2017-2
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (306, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (335, 3)
# bedflow shape for this month:  (31703, 8)
# Saved edge list for year 2017 and month 2
# Saved edge list for year 2017 and month 2
# Y-M: 2017-3
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (301, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (330, 3)
# bedflow shape for this month:  (34369, 8)
# Saved edge list for year 2017 and month 3
# Saved edge list for year 2017 and month 3
# Y-M: 2017-4
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (286, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (316, 3)
# bedflow shape for this month:  (31666, 8)
# Saved edge list for year 2017 and month 4
# Saved edge list for year 2017 and month 4
# Y-M: 2017-5
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (266, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (295, 3)
# bedflow shape for this month:  (33484, 8)
# Saved edge list for year 2017 and month 5
# Saved edge list for year 2017 and month 5
# Y-M: 2017-6
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (265, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (293, 3)
# bedflow shape for this month:  (30782, 8)
# Saved edge list for year 2017 and month 6
# Saved edge list for year 2017 and month 6
# Y-M: 2017-7
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (284, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (312, 3)
# bedflow shape for this month:  (32074, 8)
# Saved edge list for year 2017 and month 7
# Saved edge list for year 2017 and month 7
# Y-M: 2017-8
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (274, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (303, 3)
# bedflow shape for this month:  (32007, 8)
# Saved edge list for year 2017 and month 8
# Saved edge list for year 2017 and month 8
# Y-M: 2017-9
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (281, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (310, 3)
# bedflow shape for this month:  (31551, 8)
# Saved edge list for year 2017 and month 9
# Saved edge list for year 2017 and month 9
# Y-M: 2017-10
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (297, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (326, 3)
# bedflow shape for this month:  (31791, 8)
# Saved edge list for year 2017 and month 10
# Saved edge list for year 2017 and month 10
# Y-M: 2017-11
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (277, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (306, 3)
# bedflow shape for this month:  (30731, 8)
# Saved edge list for year 2017 and month 11
# Saved edge list for year 2017 and month 11
# Y-M: 2017-12
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (283, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (312, 3)
# bedflow shape for this month:  (30984, 8)
# Saved edge list for year 2017 and month 12
# Saved edge list for year 2017 and month 12
# Y-M: 2018-1
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (282, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (311, 3)
# bedflow shape for this month:  (32346, 8)
# Saved edge list for year 2018 and month 1
# Saved edge list for year 2018 and month 1
# Y-M: 2018-2
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (269, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (298, 3)
# bedflow shape for this month:  (30606, 8)
# Saved edge list for year 2018 and month 2
# Saved edge list for year 2018 and month 2
# Y-M: 2018-3
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (283, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (312, 3)
# bedflow shape for this month:  (31377, 8)
# Saved edge list for year 2018 and month 3
# Saved edge list for year 2018 and month 3
# Y-M: 2018-4
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (278, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (307, 3)
# bedflow shape for this month:  (31469, 8)
# Saved edge list for year 2018 and month 4
# Saved edge list for year 2018 and month 4
# Y-M: 2018-5
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (281, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (310, 3)
# bedflow shape for this month:  (32147, 8)
# Saved edge list for year 2018 and month 5
# Saved edge list for year 2018 and month 5
# Y-M: 2018-6
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (282, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (311, 3)
# bedflow shape for this month:  (31209, 8)
# Saved edge list for year 2018 and month 6
# Saved edge list for year 2018 and month 6
# Y-M: 2018-7
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (300, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (329, 3)
# bedflow shape for this month:  (33235, 8)
# Saved edge list for year 2018 and month 7
# Saved edge list for year 2018 and month 7
# Y-M: 2018-8
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (271, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (300, 3)
# bedflow shape for this month:  (33056, 8)
# Saved edge list for year 2018 and month 8
# Saved edge list for year 2018 and month 8
# Y-M: 2018-9
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (286, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (316, 3)
# bedflow shape for this month:  (30255, 8)
# Saved edge list for year 2018 and month 9
# Saved edge list for year 2018 and month 9
# Y-M: 2018-10
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (266, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (295, 3)
# bedflow shape for this month:  (33387, 8)
# Saved edge list for year 2018 and month 10
# Saved edge list for year 2018 and month 10
# Y-M: 2018-11
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (276, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (305, 3)
# bedflow shape for this month:  (31869, 8)
# Saved edge list for year 2018 and month 11
# Saved edge list for year 2018 and month 11
# Y-M: 2018-12
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (294, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (323, 3)
# bedflow shape for this month:  (31686, 8)
# Saved edge list for year 2018 and month 12
# Saved edge list for year 2018 and month 12
# Y-M: 2019-1
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (301, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (330, 3)
# bedflow shape for this month:  (32624, 8)
# Saved edge list for year 2019 and month 1
# Saved edge list for year 2019 and month 1
# Y-M: 2019-2
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (271, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (301, 3)
# bedflow shape for this month:  (29634, 8)
# Saved edge list for year 2019 and month 2
# Saved edge list for year 2019 and month 2
# Y-M: 2019-3
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (278, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (307, 3)
# bedflow shape for this month:  (34097, 8)
# Saved edge list for year 2019 and month 3
# Saved edge list for year 2019 and month 3
# Y-M: 2019-4
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (283, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (312, 3)
# bedflow shape for this month:  (33039, 8)
# Saved edge list for year 2019 and month 4
# Saved edge list for year 2019 and month 4
# Y-M: 2019-5
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (272, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (301, 3)
# bedflow shape for this month:  (33760, 8)
# Saved edge list for year 2019 and month 5
# Saved edge list for year 2019 and month 5
# Y-M: 2019-6
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (290, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (319, 3)
# bedflow shape for this month:  (32113, 8)
# Saved edge list for year 2019 and month 6
# Saved edge list for year 2019 and month 6
# Y-M: 2019-7
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (276, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (305, 3)
# bedflow shape for this month:  (33691, 8)
# Saved edge list for year 2019 and month 7
# Saved edge list for year 2019 and month 7
# Y-M: 2019-8
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (297, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (326, 3)
# bedflow shape for this month:  (33777, 8)
# Saved edge list for year 2019 and month 8
# Saved edge list for year 2019 and month 8
# Y-M: 2019-9
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (285, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (314, 3)
# bedflow shape for this month:  (33697, 8)
# Saved edge list for year 2019 and month 9
# Saved edge list for year 2019 and month 9
# Y-M: 2019-10
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (300, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (329, 3)
# bedflow shape for this month:  (34904, 8)
# Saved edge list for year 2019 and month 10
# Saved edge list for year 2019 and month 10
# Y-M: 2019-11
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (304, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (333, 3)
# bedflow shape for this month:  (32656, 8)
# Saved edge list for year 2019 and month 11
# Saved edge list for year 2019 and month 11
# Y-M: 2019-12
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (289, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (318, 3)
# bedflow shape for this month:  (34221, 8)
# Saved edge list for year 2019 and month 12
# Saved edge list for year 2019 and month 12
# Y-M: 2020-1
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (305, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (334, 3)
# bedflow shape for this month:  (36072, 8)
# Saved edge list for year 2020 and month 1
# Saved edge list for year 2020 and month 1
# Y-M: 2020-2
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (296, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (326, 3)
# bedflow shape for this month:  (32319, 8)
# Saved edge list for year 2020 and month 2
# Saved edge list for year 2020 and month 2
# Y-M: 2020-3
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (282, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (312, 3)
# bedflow shape for this month:  (26312, 8)
# Saved edge list for year 2020 and month 3
# Saved edge list for year 2020 and month 3
# Y-M: 2020-4
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (267, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (296, 3)
# bedflow shape for this month:  (16615, 8)
# Saved edge list for year 2020 and month 4
# Saved edge list for year 2020 and month 4
# Y-M: 2020-5
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (283, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (312, 3)
# bedflow shape for this month:  (22439, 8)
# Saved edge list for year 2020 and month 5
# Saved edge list for year 2020 and month 5
# Y-M: 2020-6
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (276, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (305, 3)
# bedflow shape for this month:  (27843, 8)
# Saved edge list for year 2020 and month 6
# Saved edge list for year 2020 and month 6
# Y-M: 2020-7
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (307, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (336, 3)
# bedflow shape for this month:  (29616, 8)
# Saved edge list for year 2020 and month 7
# Saved edge list for year 2020 and month 7
# Y-M: 2020-8
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (278, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (308, 3)
# bedflow shape for this month:  (30247, 8)
# Saved edge list for year 2020 and month 8
# Saved edge list for year 2020 and month 8
# Y-M: 2020-9
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (290, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (320, 3)
# bedflow shape for this month:  (29337, 8)
# Saved edge list for year 2020 and month 9
# Saved edge list for year 2020 and month 9
# Y-M: 2020-10
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (291, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (321, 3)
# bedflow shape for this month:  (31116, 8)
# Saved edge list for year 2020 and month 10
# Saved edge list for year 2020 and month 10
# Y-M: 2020-11
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (292, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (322, 3)
# bedflow shape for this month:  (28041, 8)
# Saved edge list for year 2020 and month 11
# Saved edge list for year 2020 and month 11
# Y-M: 2020-12
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (302, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (332, 3)
# bedflow shape for this month:  (28723, 8)
# Saved edge list for year 2020 and month 12
# Saved edge list for year 2020 and month 12
# Y-M: 2021-1
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (329, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (360, 3)
# bedflow shape for this month:  (27815, 8)
# Saved edge list for year 2021 and month 1
# Saved edge list for year 2021 and month 1
# Y-M: 2021-2
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (289, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (319, 3)
# bedflow shape for this month:  (24461, 8)
# Saved edge list for year 2021 and month 2
# Saved edge list for year 2021 and month 2
# Y-M: 2021-3
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (312, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (342, 3)
# bedflow shape for this month:  (30158, 8)
# Saved edge list for year 2021 and month 3
# Saved edge list for year 2021 and month 3
# Y-M: 2021-4
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (305, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (335, 3)
# bedflow shape for this month:  (30411, 8)
# Saved edge list for year 2021 and month 4
# Saved edge list for year 2021 and month 4
# Y-M: 2021-5
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (336, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (366, 3)
# bedflow shape for this month:  (30966, 8)
# Saved edge list for year 2021 and month 5
# Saved edge list for year 2021 and month 5
# Y-M: 2021-6
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (308, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (338, 3)
# bedflow shape for this month:  (30830, 8)
# Saved edge list for year 2021 and month 6
# Saved edge list for year 2021 and month 6
# Y-M: 2021-7
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (328, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (358, 3)
# bedflow shape for this month:  (32004, 8)
# Saved edge list for year 2021 and month 7
# Saved edge list for year 2021 and month 7
# Y-M: 2021-8
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (312, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (342, 3)
# bedflow shape for this month:  (32877, 8)
# Saved edge list for year 2021 and month 8
# Saved edge list for year 2021 and month 8
# Y-M: 2021-9
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (328, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (359, 3)
# bedflow shape for this month:  (30576, 8)
# Saved edge list for year 2021 and month 9
# Saved edge list for year 2021 and month 9
# Y-M: 2021-10
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (307, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (337, 3)
# bedflow shape for this month:  (31196, 8)
# Saved edge list for year 2021 and month 10
# Saved edge list for year 2021 and month 10
# Y-M: 2021-11
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (310, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (340, 3)
# bedflow shape for this month:  (28928, 8)
# Saved edge list for year 2021 and month 11
# Saved edge list for year 2021 and month 11
# Y-M: 2021-12
# need to remove self-edge i.e. source and dest are same
# edgelist shape without entry:  (322, 3)
# need to remove self-edge i.e. source and dest are same
# edgelist shape with entry:  (353, 3)
# bedflow shape for this month:  (30551, 8)
# Saved edge list for year 2021 and month 12
# Saved edge list for year 2021 and month 12

# %%
# converting edgelist to adjacency matrix
units = np.unique(edge_list_month_name_converted[['source', 'destination']])
adj_mat = edge_list_month_name_converted.pivot(index='source', columns='destination', 
                         values='count').reindex(columns=units, index=units, fill_value=0)
adj_mat.fillna(0, inplace=True)

# %%
adj_mat
# Out:
# destination                                         24-Hour Observation Area  \
# source
# 24-Hour Observation Area                                                 0.0
# Adult Mixed Acuity Unit                                                  0.0
# Adult Step Down Unit (post-critical care)                                0.0
# Ambulatory Surgery Center                                                0.0
# Emergency Department                                                     0.0
# Endoscopy Suite                                                          0.0
# Entry                                                                  110.0
# Exit                                                                     0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                       0.0
# Medical Cardiac Critical Care                                            0.0
# Medical Critical Care                                                    0.0
# Medical Ward                                                             0.0
# Medical/Surgical Ward                                                    0.0
# Neonatal Critical Care (Level IV)                                        0.0
# Neurologic Critical Care                                                 0.0
# Neurology Ward                                                           0.0
# Neurosurgical Ward                                                       0.0
# ONC General Hematology/Oncology Ward                                     0.0
# ONC Hematopoietic Stem Cell Transplant Ward                              0.0
# ONC Leukemia/Lymphoma Ward                                               0.0
# ONC Pediatric General Hematology/Oncology Ward                           0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                       0.0
# Operating Room/Suite                                                   277.0
# Pediatric Cardiothoracic Critical Care                                   0.0
# Pediatric Medical Ward                                                   0.0
# Pediatric Medical/Surgical Critical Care                                 0.0
# Pediatric Step Down Unit (post-critical care)                            0.0
# Pediatric Surgical Ward                                                  0.0
# Postpartum Ward                                                          0.0
# Pulmonary Ward                                                           0.0
# Step down Neonatal Nursery (Level II)                                    0.0
# Surgical Cardiothoracic Critical Care                                    0.0
# Surgical Critical Care                                                   0.0
# Surgical Ward                                                            0.0
#
# destination                                         Adult Mixed Acuity Unit  \
# source
# 24-Hour Observation Area                                                0.0
# Adult Mixed Acuity Unit                                                 0.0
# Adult Step Down Unit (post-critical care)                               0.0
# Ambulatory Surgery Center                                               0.0
# Emergency Department                                                   88.0
# Endoscopy Suite                                                         4.0
# Entry                                                                  11.0
# Exit                                                                    0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                      0.0
# Medical Cardiac Critical Care                                           3.0
# Medical Critical Care                                                  16.0
# Medical Ward                                                            4.0
# Medical/Surgical Ward                                                   0.0
# Neonatal Critical Care (Level IV)                                       0.0
# Neurologic Critical Care                                                1.0
# Neurology Ward                                                          1.0
# Neurosurgical Ward                                                      1.0
# ONC General Hematology/Oncology Ward                                    0.0
# ONC Hematopoietic Stem Cell Transplant Ward                             0.0
# ONC Leukemia/Lymphoma Ward                                              0.0
# ONC Pediatric General Hematology/Oncology Ward                          0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                      0.0
# Operating Room/Suite                                                    3.0
# Pediatric Cardiothoracic Critical Care                                  0.0
# Pediatric Medical Ward                                                  0.0
# Pediatric Medical/Surgical Critical Care                                0.0
# Pediatric Step Down Unit (post-critical care)                           0.0
# Pediatric Surgical Ward                                                 0.0
# Postpartum Ward                                                         1.0
# Pulmonary Ward                                                          0.0
# Step down Neonatal Nursery (Level II)                                   0.0
# Surgical Cardiothoracic Critical Care                                   0.0
# Surgical Critical Care                                                  5.0
# Surgical Ward                                                           0.0
#
# destination                                         Adult Step Down Unit (post-critical care)  \
# source
# 24-Hour Observation Area                                                                  0.0
# Adult Mixed Acuity Unit                                                                   0.0
# Adult Step Down Unit (post-critical care)                                                 0.0
# Ambulatory Surgery Center                                                                 0.0
# Emergency Department                                                                     34.0
# Endoscopy Suite                                                                          10.0
# Entry                                                                                    40.0
# Exit                                                                                      0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                                        0.0
# Medical Cardiac Critical Care                                                             3.0
# Medical Critical Care                                                                     0.0
# Medical Ward                                                                              1.0
# Medical/Surgical Ward                                                                     0.0
# Neonatal Critical Care (Level IV)                                                         0.0
# Neurologic Critical Care                                                                  0.0
# Neurology Ward                                                                            0.0
# Neurosurgical Ward                                                                        0.0
# ONC General Hematology/Oncology Ward                                                      0.0
# ONC Hematopoietic Stem Cell Transplant Ward                                               0.0
# ONC Leukemia/Lymphoma Ward                                                                0.0
# ONC Pediatric General Hematology/Oncology Ward                                            0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                                        0.0
# Operating Room/Suite                                                                     29.0
# Pediatric Cardiothoracic Critical Care                                                    0.0
# Pediatric Medical Ward                                                                    0.0
# Pediatric Medical/Surgical Critical Care                                                  0.0
# Pediatric Step Down Unit (post-critical care)                                             0.0
# Pediatric Surgical Ward                                                                   0.0
# Postpartum Ward                                                                           0.0
# Pulmonary Ward                                                                            0.0
# Step down Neonatal Nursery (Level II)                                                     0.0
# Surgical Cardiothoracic Critical Care                                                    51.0
# Surgical Critical Care                                                                    1.0
# Surgical Ward                                                                             0.0
#
# destination                                         Ambulatory Surgery Center  \
# source
# 24-Hour Observation Area                                                  0.0
# Adult Mixed Acuity Unit                                                   0.0
# Adult Step Down Unit (post-critical care)                                 0.0
# Ambulatory Surgery Center                                                 0.0
# Emergency Department                                                      0.0
# Endoscopy Suite                                                           0.0
# Entry                                                                   531.0
# Exit                                                                      0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                        0.0
# Medical Cardiac Critical Care                                             0.0
# Medical Critical Care                                                     0.0
# Medical Ward                                                              0.0
# Medical/Surgical Ward                                                     0.0
# Neonatal Critical Care (Level IV)                                         0.0
# Neurologic Critical Care                                                  0.0
# Neurology Ward                                                            0.0
# Neurosurgical Ward                                                        0.0
# ONC General Hematology/Oncology Ward                                      0.0
# ONC Hematopoietic Stem Cell Transplant Ward                               0.0
# ONC Leukemia/Lymphoma Ward                                                0.0
# ONC Pediatric General Hematology/Oncology Ward                            0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                        0.0
# Operating Room/Suite                                                      0.0
# Pediatric Cardiothoracic Critical Care                                    0.0
# Pediatric Medical Ward                                                    0.0
# Pediatric Medical/Surgical Critical Care                                  0.0
# Pediatric Step Down Unit (post-critical care)                             0.0
# Pediatric Surgical Ward                                                   0.0
# Postpartum Ward                                                           0.0
# Pulmonary Ward                                                            0.0
# Step down Neonatal Nursery (Level II)                                     0.0
# Surgical Cardiothoracic Critical Care                                     0.0
# Surgical Critical Care                                                    0.0
# Surgical Ward                                                             0.0
#
# destination                                         Emergency Department  \
# source
# 24-Hour Observation Area                                             0.0
# Adult Mixed Acuity Unit                                              0.0
# Adult Step Down Unit (post-critical care)                            0.0
# Ambulatory Surgery Center                                            0.0
# Emergency Department                                                 0.0
# Endoscopy Suite                                                     10.0
# Entry                                                             6180.0
# Exit                                                                 0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                   0.0
# Medical Cardiac Critical Care                                        0.0
# Medical Critical Care                                                0.0
# Medical Ward                                                         0.0
# Medical/Surgical Ward                                                0.0
# Neonatal Critical Care (Level IV)                                    0.0
# Neurologic Critical Care                                             0.0
# Neurology Ward                                                       0.0
# Neurosurgical Ward                                                   0.0
# ONC General Hematology/Oncology Ward                                 0.0
# ONC Hematopoietic Stem Cell Transplant Ward                          0.0
# ONC Leukemia/Lymphoma Ward                                           0.0
# ONC Pediatric General Hematology/Oncology Ward                       0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                   0.0
# Operating Room/Suite                                                 1.0
# Pediatric Cardiothoracic Critical Care                               0.0
# Pediatric Medical Ward                                               0.0
# Pediatric Medical/Surgical Critical Care                             0.0
# Pediatric Step Down Unit (post-critical care)                        0.0
# Pediatric Surgical Ward                                              0.0
# Postpartum Ward                                                      0.0
# Pulmonary Ward                                                       0.0
# Step down Neonatal Nursery (Level II)                                0.0
# Surgical Cardiothoracic Critical Care                                0.0
# Surgical Critical Care                                               0.0
# Surgical Ward                                                        0.0
#
# destination                                         Endoscopy Suite  Entry  \
# source
# 24-Hour Observation Area                                        0.0    0.0
# Adult Mixed Acuity Unit                                         4.0    0.0
# Adult Step Down Unit (post-critical care)                      10.0    0.0
# Ambulatory Surgery Center                                       0.0    0.0
# Emergency Department                                           11.0    0.0
# Endoscopy Suite                                                 0.0    0.0
# Entry                                                          11.0    0.0
# Exit                                                            0.0    0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)              0.0    0.0
# Medical Cardiac Critical Care                                   0.0    0.0
# Medical Critical Care                                           0.0    0.0
# Medical Ward                                                   44.0    0.0
# Medical/Surgical Ward                                          32.0    0.0
# Neonatal Critical Care (Level IV)                               0.0    0.0
# Neurologic Critical Care                                        0.0    0.0
# Neurology Ward                                                  2.0    0.0
# Neurosurgical Ward                                              4.0    0.0
# ONC General Hematology/Oncology Ward                           16.0    0.0
# ONC Hematopoietic Stem Cell Transplant Ward                     4.0    0.0
# ONC Leukemia/Lymphoma Ward                                      4.0    0.0
# ONC Pediatric General Hematology/Oncology Ward                  0.0    0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...              0.0    0.0
# Operating Room/Suite                                            0.0    0.0
# Pediatric Cardiothoracic Critical Care                          0.0    0.0
# Pediatric Medical Ward                                          0.0    0.0
# Pediatric Medical/Surgical Critical Care                        0.0    0.0
# Pediatric Step Down Unit (post-critical care)                   0.0    0.0
# Pediatric Surgical Ward                                         0.0    0.0
# Postpartum Ward                                                 0.0    0.0
# Pulmonary Ward                                                 13.0    0.0
# Step down Neonatal Nursery (Level II)                           0.0    0.0
# Surgical Cardiothoracic Critical Care                           0.0    0.0
# Surgical Critical Care                                          0.0    0.0
# Surgical Ward                                                  13.0    0.0
#
# destination                                           Exit  \
# source
# 24-Hour Observation Area                             357.0
# Adult Mixed Acuity Unit                               96.0
# Adult Step Down Unit (post-critical care)            103.0
# Ambulatory Surgery Center                            531.0
# Emergency Department                                4398.0
# Endoscopy Suite                                       11.0
# Entry                                                  0.0
# Exit                                                   0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)    69.0
# Medical Cardiac Critical Care                         38.0
# Medical Critical Care                                 33.0
# Medical Ward                                         785.0
# Medical/Surgical Ward                                419.0
# Neonatal Critical Care (Level IV)                     50.0
# Neurologic Critical Care                              54.0
# Neurology Ward                                       161.0
# Neurosurgical Ward                                   194.0
# ONC General Hematology/Oncology Ward                 365.0
# ONC Hematopoietic Stem Cell Transplant Ward           47.0
# ONC Leukemia/Lymphoma Ward                            71.0
# ONC Pediatric General Hematology/Oncology Ward        64.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...    52.0
# Operating Room/Suite                                 844.0
# Pediatric Cardiothoracic Critical Care                 7.0
# Pediatric Medical Ward                               260.0
# Pediatric Medical/Surgical Critical Care              16.0
# Pediatric Step Down Unit (post-critical care)         57.0
# Pediatric Surgical Ward                               66.0
# Postpartum Ward                                      552.0
# Pulmonary Ward                                       103.0
# Step down Neonatal Nursery (Level II)                 11.0
# Surgical Cardiothoracic Critical Care                 11.0
# Surgical Critical Care                                14.0
# Surgical Ward                                        466.0
#
# destination                                         Labor, Delivery, Recovery, Postpartum Suite (LDRP)  \
# source
# 24-Hour Observation Area                                                                          0.0
# Adult Mixed Acuity Unit                                                                           0.0
# Adult Step Down Unit (post-critical care)                                                         0.0
# Ambulatory Surgery Center                                                                         0.0
# Emergency Department                                                                              1.0
# Endoscopy Suite                                                                                   0.0
# Entry                                                                                           481.0
# Exit                                                                                              0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                                                0.0
# Medical Cardiac Critical Care                                                                     1.0
# Medical Critical Care                                                                             1.0
# Medical Ward                                                                                      0.0
# Medical/Surgical Ward                                                                             0.0
# Neonatal Critical Care (Level IV)                                                                 1.0
# Neurologic Critical Care                                                                          0.0
# Neurology Ward                                                                                    0.0
# Neurosurgical Ward                                                                                0.0
# ONC General Hematology/Oncology Ward                                                              0.0
# ONC Hematopoietic Stem Cell Transplant Ward                                                       0.0
# ONC Leukemia/Lymphoma Ward                                                                        0.0
# ONC Pediatric General Hematology/Oncology Ward                                                    0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                                                0.0
# Operating Room/Suite                                                                              1.0
# Pediatric Cardiothoracic Critical Care                                                            0.0
# Pediatric Medical Ward                                                                            0.0
# Pediatric Medical/Surgical Critical Care                                                          0.0
# Pediatric Step Down Unit (post-critical care)                                                     0.0
# Pediatric Surgical Ward                                                                           0.0
# Postpartum Ward                                                                                  16.0
# Pulmonary Ward                                                                                    0.0
# Step down Neonatal Nursery (Level II)                                                             0.0
# Surgical Cardiothoracic Critical Care                                                             0.0
# Surgical Critical Care                                                                            0.0
# Surgical Ward                                                                                     0.0
#
# destination                                         Medical Cardiac Critical Care  \
# source
# 24-Hour Observation Area                                                      0.0
# Adult Mixed Acuity Unit                                                       0.0
# Adult Step Down Unit (post-critical care)                                     1.0
# Ambulatory Surgery Center                                                     0.0
# Emergency Department                                                         46.0
# Endoscopy Suite                                                               0.0
# Entry                                                                        33.0
# Exit                                                                          0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                            1.0
# Medical Cardiac Critical Care                                                 0.0
# Medical Critical Care                                                         0.0
# Medical Ward                                                                 31.0
# Medical/Surgical Ward                                                         3.0
# Neonatal Critical Care (Level IV)                                             0.0
# Neurologic Critical Care                                                      1.0
# Neurology Ward                                                                2.0
# Neurosurgical Ward                                                            1.0
# ONC General Hematology/Oncology Ward                                          4.0
# ONC Hematopoietic Stem Cell Transplant Ward                                   0.0
# ONC Leukemia/Lymphoma Ward                                                    1.0
# ONC Pediatric General Hematology/Oncology Ward                                0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                            0.0
# Operating Room/Suite                                                         15.0
# Pediatric Cardiothoracic Critical Care                                        0.0
# Pediatric Medical Ward                                                        0.0
# Pediatric Medical/Surgical Critical Care                                      0.0
# Pediatric Step Down Unit (post-critical care)                                 0.0
# Pediatric Surgical Ward                                                       0.0
# Postpartum Ward                                                               0.0
# Pulmonary Ward                                                                1.0
# Step down Neonatal Nursery (Level II)                                         0.0
# Surgical Cardiothoracic Critical Care                                         2.0
# Surgical Critical Care                                                        2.0
# Surgical Ward                                                                 4.0
#
# destination                                         ...  \
# source                                              ...
# 24-Hour Observation Area                            ...
# Adult Mixed Acuity Unit                             ...
# Adult Step Down Unit (post-critical care)           ...
# Ambulatory Surgery Center                           ...
# Emergency Department                                ...
# Endoscopy Suite                                     ...
# Entry                                               ...
# Exit                                                ...
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)  ...
# Medical Cardiac Critical Care                       ...
# Medical Critical Care                               ...
# Medical Ward                                        ...
# Medical/Surgical Ward                               ...
# Neonatal Critical Care (Level IV)                   ...
# Neurologic Critical Care                            ...
# Neurology Ward                                      ...
# Neurosurgical Ward                                  ...
# ONC General Hematology/Oncology Ward                ...
# ONC Hematopoietic Stem Cell Transplant Ward         ...
# ONC Leukemia/Lymphoma Ward                          ...
# ONC Pediatric General Hematology/Oncology Ward      ...
# ONC Pediatric Hematopoietic Stem Cell Transplan...  ...
# Operating Room/Suite                                ...
# Pediatric Cardiothoracic Critical Care              ...
# Pediatric Medical Ward                              ...
# Pediatric Medical/Surgical Critical Care            ...
# Pediatric Step Down Unit (post-critical care)       ...
# Pediatric Surgical Ward                             ...
# Postpartum Ward                                     ...
# Pulmonary Ward                                      ...
# Step down Neonatal Nursery (Level II)               ...
# Surgical Cardiothoracic Critical Care               ...
# Surgical Critical Care                              ...
# Surgical Ward                                       ...
#
# destination                                         Pediatric Medical Ward  \
# source
# 24-Hour Observation Area                                               0.0
# Adult Mixed Acuity Unit                                                0.0
# Adult Step Down Unit (post-critical care)                              0.0
# Ambulatory Surgery Center                                              0.0
# Emergency Department                                                 119.0
# Endoscopy Suite                                                        0.0
# Entry                                                                 44.0
# Exit                                                                   0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                     1.0
# Medical Cardiac Critical Care                                          0.0
# Medical Critical Care                                                  0.0
# Medical Ward                                                           0.0
# Medical/Surgical Ward                                                  0.0
# Neonatal Critical Care (Level IV)                                      6.0
# Neurologic Critical Care                                               0.0
# Neurology Ward                                                         0.0
# Neurosurgical Ward                                                     0.0
# ONC General Hematology/Oncology Ward                                   1.0
# ONC Hematopoietic Stem Cell Transplant Ward                            0.0
# ONC Leukemia/Lymphoma Ward                                             0.0
# ONC Pediatric General Hematology/Oncology Ward                        20.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                     0.0
# Operating Room/Suite                                                  69.0
# Pediatric Cardiothoracic Critical Care                                 3.0
# Pediatric Medical Ward                                                 0.0
# Pediatric Medical/Surgical Critical Care                              40.0
# Pediatric Step Down Unit (post-critical care)                          6.0
# Pediatric Surgical Ward                                                1.0
# Postpartum Ward                                                        2.0
# Pulmonary Ward                                                         0.0
# Step down Neonatal Nursery (Level II)                                  0.0
# Surgical Cardiothoracic Critical Care                                  0.0
# Surgical Critical Care                                                 0.0
# Surgical Ward                                                          0.0
#
# destination                                         Pediatric Medical/Surgical Critical Care  \
# source
# 24-Hour Observation Area                                                                 0.0
# Adult Mixed Acuity Unit                                                                  0.0
# Adult Step Down Unit (post-critical care)                                                0.0
# Ambulatory Surgery Center                                                                0.0
# Emergency Department                                                                    30.0
# Endoscopy Suite                                                                          0.0
# Entry                                                                                   24.0
# Exit                                                                                     0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                                       0.0
# Medical Cardiac Critical Care                                                            0.0
# Medical Critical Care                                                                    0.0
# Medical Ward                                                                             0.0
# Medical/Surgical Ward                                                                    0.0
# Neonatal Critical Care (Level IV)                                                        1.0
# Neurologic Critical Care                                                                 0.0
# Neurology Ward                                                                           0.0
# Neurosurgical Ward                                                                       0.0
# ONC General Hematology/Oncology Ward                                                     0.0
# ONC Hematopoietic Stem Cell Transplant Ward                                              0.0
# ONC Leukemia/Lymphoma Ward                                                               0.0
# ONC Pediatric General Hematology/Oncology Ward                                           3.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                                       1.0
# Operating Room/Suite                                                                    31.0
# Pediatric Cardiothoracic Critical Care                                                   2.0
# Pediatric Medical Ward                                                                   4.0
# Pediatric Medical/Surgical Critical Care                                                 0.0
# Pediatric Step Down Unit (post-critical care)                                            6.0
# Pediatric Surgical Ward                                                                  1.0
# Postpartum Ward                                                                          0.0
# Pulmonary Ward                                                                           0.0
# Step down Neonatal Nursery (Level II)                                                    0.0
# Surgical Cardiothoracic Critical Care                                                    0.0
# Surgical Critical Care                                                                   0.0
# Surgical Ward                                                                            0.0
#
# destination                                         Pediatric Step Down Unit (post-critical care)  \
# source
# 24-Hour Observation Area                                                                      0.0
# Adult Mixed Acuity Unit                                                                       0.0
# Adult Step Down Unit (post-critical care)                                                     0.0
# Ambulatory Surgery Center                                                                     0.0
# Emergency Department                                                                         14.0
# Endoscopy Suite                                                                               0.0
# Entry                                                                                        22.0
# Exit                                                                                          0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                                            0.0
# Medical Cardiac Critical Care                                                                 0.0
# Medical Critical Care                                                                         0.0
# Medical Ward                                                                                  0.0
# Medical/Surgical Ward                                                                         0.0
# Neonatal Critical Care (Level IV)                                                             1.0
# Neurologic Critical Care                                                                      0.0
# Neurology Ward                                                                                0.0
# Neurosurgical Ward                                                                            0.0
# ONC General Hematology/Oncology Ward                                                          0.0
# ONC Hematopoietic Stem Cell Transplant Ward                                                   0.0
# ONC Leukemia/Lymphoma Ward                                                                    0.0
# ONC Pediatric General Hematology/Oncology Ward                                                0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                                            0.0
# Operating Room/Suite                                                                          2.0
# Pediatric Cardiothoracic Critical Care                                                       30.0
# Pediatric Medical Ward                                                                        2.0
# Pediatric Medical/Surgical Critical Care                                                     11.0
# Pediatric Step Down Unit (post-critical care)                                                 0.0
# Pediatric Surgical Ward                                                                       0.0
# Postpartum Ward                                                                               0.0
# Pulmonary Ward                                                                                0.0
# Step down Neonatal Nursery (Level II)                                                         0.0
# Surgical Cardiothoracic Critical Care                                                         0.0
# Surgical Critical Care                                                                        0.0
# Surgical Ward                                                                                 0.0
#
# destination                                         Pediatric Surgical Ward  \
# source
# 24-Hour Observation Area                                                0.0
# Adult Mixed Acuity Unit                                                 0.0
# Adult Step Down Unit (post-critical care)                               0.0
# Ambulatory Surgery Center                                               0.0
# Emergency Department                                                   19.0
# Endoscopy Suite                                                         0.0
# Entry                                                                   4.0
# Exit                                                                    0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                      0.0
# Medical Cardiac Critical Care                                           0.0
# Medical Critical Care                                                   0.0
# Medical Ward                                                            0.0
# Medical/Surgical Ward                                                   0.0
# Neonatal Critical Care (Level IV)                                       0.0
# Neurologic Critical Care                                                0.0
# Neurology Ward                                                          0.0
# Neurosurgical Ward                                                      0.0
# ONC General Hematology/Oncology Ward                                    0.0
# ONC Hematopoietic Stem Cell Transplant Ward                             0.0
# ONC Leukemia/Lymphoma Ward                                              0.0
# ONC Pediatric General Hematology/Oncology Ward                          0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                      0.0
# Operating Room/Suite                                                   48.0
# Pediatric Cardiothoracic Critical Care                                  0.0
# Pediatric Medical Ward                                                  9.0
# Pediatric Medical/Surgical Critical Care                               14.0
# Pediatric Step Down Unit (post-critical care)                           0.0
# Pediatric Surgical Ward                                                 0.0
# Postpartum Ward                                                         1.0
# Pulmonary Ward                                                          0.0
# Step down Neonatal Nursery (Level II)                                   0.0
# Surgical Cardiothoracic Critical Care                                   1.0
# Surgical Critical Care                                                  0.0
# Surgical Ward                                                           0.0
#
# destination                                         Postpartum Ward  \
# source
# 24-Hour Observation Area                                        0.0
# Adult Mixed Acuity Unit                                         0.0
# Adult Step Down Unit (post-critical care)                       0.0
# Ambulatory Surgery Center                                       0.0
# Emergency Department                                            0.0
# Endoscopy Suite                                                 0.0
# Entry                                                         160.0
# Exit                                                            0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)            410.0
# Medical Cardiac Critical Care                                   0.0
# Medical Critical Care                                           1.0
# Medical Ward                                                    0.0
# Medical/Surgical Ward                                           0.0
# Neonatal Critical Care (Level IV)                              10.0
# Neurologic Critical Care                                        0.0
# Neurology Ward                                                  0.0
# Neurosurgical Ward                                              0.0
# ONC General Hematology/Oncology Ward                            0.0
# ONC Hematopoietic Stem Cell Transplant Ward                     0.0
# ONC Leukemia/Lymphoma Ward                                      0.0
# ONC Pediatric General Hematology/Oncology Ward                  0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...              0.0
# Operating Room/Suite                                            3.0
# Pediatric Cardiothoracic Critical Care                          1.0
# Pediatric Medical Ward                                          0.0
# Pediatric Medical/Surgical Critical Care                        0.0
# Pediatric Step Down Unit (post-critical care)                   0.0
# Pediatric Surgical Ward                                         0.0
# Postpartum Ward                                                 0.0
# Pulmonary Ward                                                  0.0
# Step down Neonatal Nursery (Level II)                           0.0
# Surgical Cardiothoracic Critical Care                           0.0
# Surgical Critical Care                                          2.0
# Surgical Ward                                                   0.0
#
# destination                                         Pulmonary Ward  \
# source
# 24-Hour Observation Area                                       0.0
# Adult Mixed Acuity Unit                                        1.0
# Adult Step Down Unit (post-critical care)                      1.0
# Ambulatory Surgery Center                                      0.0
# Emergency Department                                          66.0
# Endoscopy Suite                                               14.0
# Entry                                                         30.0
# Exit                                                           0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)             0.0
# Medical Cardiac Critical Care                                  1.0
# Medical Critical Care                                         10.0
# Medical Ward                                                   2.0
# Medical/Surgical Ward                                          5.0
# Neonatal Critical Care (Level IV)                              0.0
# Neurologic Critical Care                                       0.0
# Neurology Ward                                                 0.0
# Neurosurgical Ward                                             0.0
# ONC General Hematology/Oncology Ward                           0.0
# ONC Hematopoietic Stem Cell Transplant Ward                    0.0
# ONC Leukemia/Lymphoma Ward                                     0.0
# ONC Pediatric General Hematology/Oncology Ward                 0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...             0.0
# Operating Room/Suite                                          10.0
# Pediatric Cardiothoracic Critical Care                         0.0
# Pediatric Medical Ward                                         0.0
# Pediatric Medical/Surgical Critical Care                       0.0
# Pediatric Step Down Unit (post-critical care)                  0.0
# Pediatric Surgical Ward                                        0.0
# Postpartum Ward                                                0.0
# Pulmonary Ward                                                 0.0
# Step down Neonatal Nursery (Level II)                          0.0
# Surgical Cardiothoracic Critical Care                          2.0
# Surgical Critical Care                                         1.0
# Surgical Ward                                                  0.0
#
# destination                                         Step down Neonatal Nursery (Level II)  \
# source
# 24-Hour Observation Area                                                              0.0
# Adult Mixed Acuity Unit                                                               0.0
# Adult Step Down Unit (post-critical care)                                             0.0
# Ambulatory Surgery Center                                                             0.0
# Emergency Department                                                                  0.0
# Endoscopy Suite                                                                       0.0
# Entry                                                                                 0.0
# Exit                                                                                  0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                                    0.0
# Medical Cardiac Critical Care                                                         0.0
# Medical Critical Care                                                                 0.0
# Medical Ward                                                                          0.0
# Medical/Surgical Ward                                                                 0.0
# Neonatal Critical Care (Level IV)                                                    26.0
# Neurologic Critical Care                                                              0.0
# Neurology Ward                                                                        0.0
# Neurosurgical Ward                                                                    0.0
# ONC General Hematology/Oncology Ward                                                  0.0
# ONC Hematopoietic Stem Cell Transplant Ward                                           0.0
# ONC Leukemia/Lymphoma Ward                                                            0.0
# ONC Pediatric General Hematology/Oncology Ward                                        0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                                    0.0
# Operating Room/Suite                                                                  0.0
# Pediatric Cardiothoracic Critical Care                                                0.0
# Pediatric Medical Ward                                                                0.0
# Pediatric Medical/Surgical Critical Care                                              0.0
# Pediatric Step Down Unit (post-critical care)                                         0.0
# Pediatric Surgical Ward                                                               0.0
# Postpartum Ward                                                                       0.0
# Pulmonary Ward                                                                        0.0
# Step down Neonatal Nursery (Level II)                                                 0.0
# Surgical Cardiothoracic Critical Care                                                 0.0
# Surgical Critical Care                                                                0.0
# Surgical Ward                                                                         0.0
#
# destination                                         Surgical Cardiothoracic Critical Care  \
# source
# 24-Hour Observation Area                                                              0.0
# Adult Mixed Acuity Unit                                                               0.0
# Adult Step Down Unit (post-critical care)                                             3.0
# Ambulatory Surgery Center                                                             0.0
# Emergency Department                                                                 13.0
# Endoscopy Suite                                                                       0.0
# Entry                                                                                11.0
# Exit                                                                                  0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                                    0.0
# Medical Cardiac Critical Care                                                         1.0
# Medical Critical Care                                                                 0.0
# Medical Ward                                                                          2.0
# Medical/Surgical Ward                                                                 7.0
# Neonatal Critical Care (Level IV)                                                     0.0
# Neurologic Critical Care                                                              0.0
# Neurology Ward                                                                        0.0
# Neurosurgical Ward                                                                    0.0
# ONC General Hematology/Oncology Ward                                                  0.0
# ONC Hematopoietic Stem Cell Transplant Ward                                           0.0
# ONC Leukemia/Lymphoma Ward                                                            0.0
# ONC Pediatric General Hematology/Oncology Ward                                        0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                                    0.0
# Operating Room/Suite                                                                221.0
# Pediatric Cardiothoracic Critical Care                                                0.0
# Pediatric Medical Ward                                                                0.0
# Pediatric Medical/Surgical Critical Care                                              0.0
# Pediatric Step Down Unit (post-critical care)                                         0.0
# Pediatric Surgical Ward                                                               0.0
# Postpartum Ward                                                                       0.0
# Pulmonary Ward                                                                        1.0
# Step down Neonatal Nursery (Level II)                                                 0.0
# Surgical Cardiothoracic Critical Care                                                 0.0
# Surgical Critical Care                                                                3.0
# Surgical Ward                                                                         0.0
#
# destination                                         Surgical Critical Care  \
# source
# 24-Hour Observation Area                                               0.0
# Adult Mixed Acuity Unit                                                3.0
# Adult Step Down Unit (post-critical care)                              0.0
# Ambulatory Surgery Center                                              0.0
# Emergency Department                                                  37.0
# Endoscopy Suite                                                        0.0
# Entry                                                                  5.0
# Exit                                                                   0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)                     0.0
# Medical Cardiac Critical Care                                          0.0
# Medical Critical Care                                                  1.0
# Medical Ward                                                           5.0
# Medical/Surgical Ward                                                  4.0
# Neonatal Critical Care (Level IV)                                      0.0
# Neurologic Critical Care                                               2.0
# Neurology Ward                                                         1.0
# Neurosurgical Ward                                                     0.0
# ONC General Hematology/Oncology Ward                                   0.0
# ONC Hematopoietic Stem Cell Transplant Ward                            0.0
# ONC Leukemia/Lymphoma Ward                                             1.0
# ONC Pediatric General Hematology/Oncology Ward                         0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...                     0.0
# Operating Room/Suite                                                 107.0
# Pediatric Cardiothoracic Critical Care                                 0.0
# Pediatric Medical Ward                                                 0.0
# Pediatric Medical/Surgical Critical Care                               0.0
# Pediatric Step Down Unit (post-critical care)                          0.0
# Pediatric Surgical Ward                                                0.0
# Postpartum Ward                                                        0.0
# Pulmonary Ward                                                         0.0
# Step down Neonatal Nursery (Level II)                                  0.0
# Surgical Cardiothoracic Critical Care                                  0.0
# Surgical Critical Care                                                 0.0
# Surgical Ward                                                          4.0
#
# destination                                         Surgical Ward
# source
# 24-Hour Observation Area                                     16.0
# Adult Mixed Acuity Unit                                       2.0
# Adult Step Down Unit (post-critical care)                     2.0
# Ambulatory Surgery Center                                     0.0
# Emergency Department                                        176.0
# Endoscopy Suite                                              14.0
# Entry                                                        59.0
# Exit                                                          0.0
# Labor, Delivery, Recovery, Postpartum Suite (LDRP)            0.0
# Medical Cardiac Critical Care                                 0.0
# Medical Critical Care                                         1.0
# Medical Ward                                                  0.0
# Medical/Surgical Ward                                        17.0
# Neonatal Critical Care (Level IV)                             0.0
# Neurologic Critical Care                                      1.0
# Neurology Ward                                                3.0
# Neurosurgical Ward                                            1.0
# ONC General Hematology/Oncology Ward                          0.0
# ONC Hematopoietic Stem Cell Transplant Ward                   0.0
# ONC Leukemia/Lymphoma Ward                                    0.0
# ONC Pediatric General Hematology/Oncology Ward                0.0
# ONC Pediatric Hematopoietic Stem Cell Transplan...            0.0
# Operating Room/Suite                                        273.0
# Pediatric Cardiothoracic Critical Care                        0.0
# Pediatric Medical Ward                                        1.0
# Pediatric Medical/Surgical Critical Care                      0.0
# Pediatric Step Down Unit (post-critical care)                 0.0
# Pediatric Surgical Ward                                       0.0
# Postpartum Ward                                               1.0
# Pulmonary Ward                                                1.0
# Step down Neonatal Nursery (Level II)                         0.0
# Surgical Cardiothoracic Critical Care                         0.0
# Surgical Critical Care                                       37.0
# Surgical Ward                                                 0.0
#
# [34 rows x 34 columns]
